# %% [markdown]
# # Course End Project: Data Analysis Module
# Exploratory Data Analysis
#
#
# > Tasks:

# %% [markdown]
# ---
#
# # 1. Data Loading and Initial Exploration:
#
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt     #for visualization
import seaborn as sns               #for visualization
import chardet

# %%
with open("/content/drive/MyDrive/Airbnb Data/Listings.csv", 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']

# %%
listings = pd.read_csv("/content/drive/MyDrive/Airbnb Data/Listings.csv", encoding=encoding)
# Out:
# <ipython-input-4-9245f09d44d7>:1: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   listings = pd.read_csv("/content/drive/MyDrive/Airbnb Data/Listings.csv", encoding=encoding)

# %%
Listings_data_dictionary= pd.read_csv("/content/drive/MyDrive/Airbnb Data/Listings_data_dictionary.csv")

# %%
reviwes= pd.read_csv("/content/drive/MyDrive/Airbnb Data/Reviews.csv")

# %%
Reviews_data_dictionary= pd.read_csv("/content/drive/MyDrive/Airbnb Data/Reviews_data_dictionary.csv")

# %%
Listings_data_dictionary
# Out:
#                           Field  \
# 0                    listing_id
# 1                          name
# 2                       host_id
# 3                    host_since
# 4                 host_location
# 5            host_response_time
# 6            host_response_rate
# 7          host_acceptance_rate
# 8             host_is_superhost
# 9     host_total_listings_count
# 10         host_has_profile_pic
# 11       host_identity_verified
# 12                neighbourhood
# 13                     district
# 14                         city
# 15                     latitude
# 16                    longitude
# 17                property_type
# 18                    room_type
# 19                 accommodates
# 20                     bedrooms
# 21                    amenities
# 22                        price
# 23               minimum_nights
# 24               maximum_nights
# 25         review_scores_rating
# 26       review_scores_accuracy
# 27    review_scores_cleanliness
# ...

# %%
Reviews_data_dictionary

# %%
reviwes.head()
# Out:
#    listing_id  review_id        date  reviewer_id
# 0       11798  330265172  2018-09-30     11863072
# 1       15383  330103585  2018-09-30     39147453
# 2       16455  329985788  2018-09-30      1125378
# 3       17919  330016899  2018-09-30    172717984
# 4       26827  329995638  2018-09-30     17542859

# %%
reviwes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5373143 entries, 0 to 5373142
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   listing_id   int64
#  1   review_id    int64
#  2   date         object
#  3   reviewer_id  int64
# dtypes: int64(3), object(1)
# memory usage: 164.0+ MB

# %%
reviwes.isnull().sum()
# Out:
# listing_id     0
# review_id      0
# date           0
# reviewer_id    0
# dtype: int64

# %%
listings.head()
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                   39 mÂ² Paris (Sacre CÅ“ur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#    host_since                 host_location host_is_superhost  \
# 0  2011-12-03  Paris, Ile-de-France, France                 f
# 1  2013-11-29  Paris, Ile-de-France, France                 f
# 2  2014-07-31  Paris, Ile-de-France, France                 f
# 3  2013-12-17  Paris, Ile-de-France, France                 f
# 4  2014-12-14  Paris, Ile-de-France, France                 f
#
#    host_total_listings_count      neighbourhood district   city  ...  \
# 0                        1.0  Buttes-Montmartre      NaN  Paris  ...
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279712 entries, 0 to 279711
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   listing_id                   279712 non-null  int64
#  1   name                         279539 non-null  object
#  2   host_id                      279712 non-null  int64
#  3   host_since                   279547 non-null  object
#  4   host_location                278872 non-null  object
#  5   host_response_time           150930 non-null  object
#  6   host_response_rate           150930 non-null  float64
#  7   host_acceptance_rate         166625 non-null  float64
#  8   host_is_superhost            279547 non-null  object
#  9   host_total_listings_count    279547 non-null  float64
#  10  host_has_profile_pic         279547 non-null  object
#  11  host_identity_verified       279547 non-null  object
# ...

# %%
listings.isnull().sum()
# Out:
# listing_id                          0
# name                              173
# host_id                             0
# host_since                        165
# host_location                     840
# host_response_time             128782
# host_response_rate             128782
# host_acceptance_rate           113087
# host_is_superhost                 165
# host_total_listings_count         165
# host_has_profile_pic              165
# host_identity_verified            165
# neighbourhood                       0
# district                       242700
# city                                0
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bedrooms                        29435
# amenities                           0
# price                               0
# minimum_nights                      0
# maximum_nights                      0
# ...

# %%
listings.shape
# Out:
# (279712, 33)

# %% [markdown]
# ---
#
# # 2. Data Cleaning:
#
#
# ---

# %%
listings.name.fillna("User",inplace=True)

# %%
listings.host_since.fillna("0000-00-00",inplace=True)

# %%
 mode_location =listings['host_location'].mode()[0]
 mode_location
# Out:
# 'Paris, Ile-de-France, France'

# %%
listings['host_location'].fillna(mode_location, inplace=True)

# %%
listings.drop(['host_response_time','host_response_rate','host_acceptance_rate'], axis=1, inplace=True)

# %%
mode_superhost = listings['host_is_superhost'].mode()[0]
mode_superhost
# Out:
# 'f'

# %%
listings['host_is_superhost'].fillna(mode_superhost, inplace=True)

# %%
listings['host_is_superhost'].replace({'false': 0, 'true': 1}, inplace=True)

# %%
listings.district.mode()[0]
# Out:
# 'Manhattan'

# %%
listings['district'].fillna('Unknown', inplace=True)

# %%
listings.bedrooms.mode()[0]
# Out:
# 1.0

# %%
listings.bedrooms.fillna(listings.bedrooms.mode()[0],inplace=True)

# %%
mean_rating = listings['review_scores_rating'].mean()
listings['review_scores_rating'].fillna(mean_rating, inplace=True)

# %%
mean_accuracy = listings['review_scores_accuracy'].mean()
listings['review_scores_accuracy'].fillna(mean_accuracy, inplace=True)

# %%
mean_cleanliness = listings['review_scores_cleanliness'].mean()
listings['review_scores_cleanliness'].fillna(mean_cleanliness, inplace=True)

# %%
mean_checkin = listings['review_scores_checkin'].mean()
listings['review_scores_checkin'].fillna(mean_checkin, inplace=True)

# %%
mean_communication = listings['review_scores_communication'].mean()
listings['review_scores_communication'].fillna(mean_communication, inplace=True)

# %%
mean_location = listings['review_scores_location'].mean()
listings['review_scores_location'].fillna(mean_location, inplace=True)

# %%
mean_value = listings['review_scores_value'].mean()
listings['review_scores_value'].fillna(mean_value, inplace=True)

# %%
listings.duplicated().sum()
# Out:
# 0

# %%
listings=listings.dropna()

# %%
listings.isnull().sum()
# Out:
# listing_id                     0
# name                           0
# host_id                        0
# host_since                     0
# host_location                  0
# host_is_superhost              0
# host_total_listings_count      0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# district                       0
# city                           0
# latitude                       0
# longitude                      0
# property_type                  0
# room_type                      0
# accommodates                   0
# bedrooms                       0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# ...

# %% [markdown]
# ---
#
# 3. Exploratory Data Analysis:
#
#
# ---

# %%
# Visualize the count of each room type
sns.countplot(x=listings['room_type'], palette="plasma")
plt.title('Type of room in Airbnb Listings')
plt.xlabel('Room Type')
plt.ylabel('Count')

plt.show()
# Out:
# <ipython-input-37-ae45cf3d5780>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=listings['room_type'], palette="plasma")

# %%
def categorise(hotel_price):
    if hotel_price<=75:
        return 'Low'
    elif hotel_price >75 and hotel_price<=500:
        return 'Medium'
    else:
        return 'High'
listings['price'].apply(categorise).value_counts().plot(kind='bar')
plt.show()

# %%
listings['city'].value_counts().plot(kind='line',marker='o', color='#CA4040')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.title('Distribution of Listings by City')
plt.show()

# %%
# Bivariate analysis - Price vs. Room Type
plt.figure(figsize=(10, 6))
sns.boxplot(data=listings, x='price', y='room_type')
plt.title('Price Distribution by Room Type')
plt.xlabel('Price')
plt.ylabel('Room Type')
plt.xlim(0, listings['price'].quantile(0.95))  # Limiting x-axis to 95th percentile for better visibility
plt.show()

# %%
# count the hosts joined each month
hosts_per_month = listings['host_since'].value_counts().sort_index()

#plot the trend of hosts joining
plt.figure(figsize = (10,6))
hosts_per_month.plot(kind = 'line', marker = '.', color = '#051399')
plt.title('Number of Hosts Joined Airbnb Overtime')
plt.xlabel('Year-Month')
plt.ylabel('Number of Hosts Joined')
plt.xticks(rotation = 45)
plt.grid(True)
plt.show()

# %%
pd.pivot_table(data=listings, index='city', values='listing_id',columns='host_is_superhost',aggfunc='count').plot.bar()
plt.ylabel('Count')
plt.legend(['non-superhost','superhost'])
plt.title('Superhost status in cities on Airbnb')
# Out:
# Text(0.5, 1.0, 'Superhost status in cities on Airbnb')

# %%
listings.groupby(['host_is_superhost'])['price'].mean().sort_values(ascending=False).plot.bar(color='green')
plt.title('The ralation between price and superhost status')
plt.ylabel('Price')
plt.xlabel('Superhost Status')
plt.xticks([0,1],['Superhost','non-superhost'])
# Out:
# ([<matplotlib.axis.XTick at 0x7b13e05aacb0>,
# ...
#  [Text(0, 0, 'Superhost'), Text(1, 0, 'non-superhost')])

# %%
listings.groupby(['property_type'])['price'].mean().sort_values(ascending=False)[:10].plot.bar(color='#c16bfa')
plt.title('Top 10 expensive host propert type')
plt.ylabel('Price')
plt.xlabel('Host property type')
# Out:
# Text(0.5, 0, 'Host property type')

# %%
listings.groupby(['room_type'])['price'].mean().sort_values(ascending=False).plot.bar(color='#fa6be0')
plt.title('The ralation between price with room type')
plt.ylabel('Price')
plt.xlabel('Room type')
# Out:
# Text(0.5, 0, 'Room type')

# %%
sorted_data = listings.sort_values(by='review_scores_location', ascending=False)

N = 7
top_hotels = sorted_data.head(N)

plt.figure(figsize=(10, 8))
plt.barh(top_hotels['name'], top_hotels['review_scores_location'], color='lightblue')
plt.xlabel('review_scores_location')
plt.ylabel('Hotel Name')
plt.title('Top Rated Hotels')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ---
#
# # 4. Feature Engineering:
#
#
# ---

# %%
# Feature Engineering

# 1. Average Rating
rating_columns = ['review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
                  'review_scores_communication', 'review_scores_location', 'review_scores_value']
listings['average_rating'] = listings[rating_columns].mean(axis=1)


listings['estimated_occupancy'] = listings['review_scores_rating'].fillna(0) / 100

# %%
# To avoid division by zero, we'll replace 0 bedrooms with 1 (assuming at least 1 bedroom or studio)
listings['bedrooms'] = listings['bedrooms'].replace(0, 1)
listings['price_per_bedroom'] = listings['price'] / listings['bedrooms']

# Overview of the new features
new_features_overview = listings[['average_rating', 'estimated_occupancy', 'price_per_bedroom']].describe()

new_features_overview
# Out:
#        average_rating  estimated_occupancy  price_per_bedroom
# count   279547.000000        279547.000000      279547.000000
# mean         9.541297             0.934053         392.611628
# std          0.642293             0.082632        2586.702133
# min          2.000000             0.200000           0.000000
# 25%          9.541305             0.934052          65.000000
# 50%          9.541305             0.934052         118.000000
# 75%          9.833333             0.980000         347.000000
# max         10.000000             1.000000      625216.000000

# %%
# Data Visualization for New Features

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Visualization - Distribution of Average Rating
plt.figure(figsize=(10, 6))
sns.histplot(listings['average_rating'], bins=30, kde=True, color='purple')
plt.title('Distribution of Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualization - Estimated Occupancy Rate
plt.figure(figsize=(10, 6))
sns.histplot(lis['estimated_occupancy'], bins=30, kde=True, color='orange')
plt.title('Estimated Occupancy Rate')
plt.xlabel('Occupancy Rate')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ---
#
# # 5. Hypothesis Testing
#
# ---

# %%
listings.room_type.unique()
# Out:
# array(['Entire place', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
from scipy import stats

# Assuming you have loaded the dataset and named it 'listings'

# Subset the data for the two room types you want to compare
room_type1 = listings[listings['room_type'] == 'Entire place']
room_type2 = listings[listings['room_type'] == 'Private room']

# Extract the price data for each room type
prices1 = room_type1['price']
prices2 = room_type2['price']

# Perform independent samples t-test
t_statistic, p_value = stats.ttest_ind(prices1, prices2)

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 15.739009918944078
# P-value: 8.654747851170298e-56

# %% [markdown]
# ---
#
# # 6. Conclusion:
#
#
# ---

# %% [markdown]
# #   Findings:
#
#
# *  Dataset with over 279k entries and 33 columns.
# *  Missing values handled; no duplicates found.
# * New features like average rating and estimated occupancy created.
#
# #   Insights:
# * Price distribution skewed towards lower-end listings.
# * Potential relationships between price and property/room types.
# * Average rating could indicate guest satisfaction levels.
#
# #  Recommendations:
#
# * Pricing Strategy: Hosts can adjust their pricing strategies based on the room type and market demand. Understanding the average prices for different types of accommodations can assist hosts in setting competitive rates.
#
# * Customer Satisfaction: Hosts can focus on improving the quality of their listings by considering the feedback provided in customer reviews. Addressing any recurring issues or concerns could enhance customer satisfaction and lead to positive reviews.
#
# * Market Analysis: Analyzing the distribution of listings across neighborhoods or cities can help hosts identify potential opportunities in underserved areas. It can also provide insights into market trends and preferences, guiding hosts in making informed decisions about where to invest in new listings.
#
# * Competitor Analysis: Hosts can study the pricing and amenities offered by their competitors in the same area. This analysis can help them differentiate their listings and identify any gaps in the market that they can leverage.
#
# .
#
# Overall, the exploratory data analysis provides valuable insights for hosts and potential travelers, enabling them to make informed decisions regarding pricing, customer satisfaction, and market opportunities.
